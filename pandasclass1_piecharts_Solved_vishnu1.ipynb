# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data2 = {
    "Name":["alice","bob","cathy"],
    "Age":[25,56,45]
}
df=pd.DataFrame(data2)
print(df)
# Out:
#     Name  Age
# 0  alice   25
# 1    bob   56
# 2  cathy   45

# %%
plt.bar(data2["Name"], data2["Age"])
plt.title("Age bar")
plt.xlabel("Name")
plt.ylabel("Age")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('C:\\Users\\vishnu1\\OneDrive - NetApp Inc\\Documents\\data1.csv')

plt.bar(df1["Name"], df1["Age"])
plt.title("Age bar")
plt.xlabel("Name")
plt.ylabel("Age")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('C:\\Users\\vishnu1\\OneDrive - NetApp Inc\\Documents\\data1.csv')

plt.pie(df1['Age'], labels=df1['Name'])
plt.title('pie chart')
plt.show()
